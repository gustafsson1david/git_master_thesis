# %%
from gensim.models.keyedvectors import KeyedVectors
w2v = KeyedVectors.load_word2vec_format('../../../data/GoogleNews-vectors-negative300.bin', binary=True)

# %%
original_names = [
    r'airport\airport',
    r'alley',
    r'amusement_park',
    r'art_gallery',
    r'bakery\shop',
    r'bar',
    r'basketball_court\indoor',
    r'bathroom',
    r'beach',
    r'beer_garden',
    r'bicycle_racks',
    r'botanical_garden',
    r'bowling_alley',
    r'boxing_ring',
    r'brewery\indoor',
    r'bridge',
    r'bus_depot\outdoor',
    r'canal\urban',
    r'casino\indoor',
    r'castle',
    r'cathedral\indoor',
    r'cemetery',
    r'chalet',
    r'church\outdoor',
    r'city',
    r'classroom',
    r'desert\sand',
    r'dining_hall',
    r'discotheque',
    r'dock',
    r'driving_range\outdoor',
    r'factory\indoor',
    r'field\wild',
    r'field_road',
    r'fishpond',
    r'florist_shop\indoor',
    r'forest_path',
    r'fountain',
    r'freeway',
    r'gymnasium\indoor',
    r'harbor',
    r'hospital_room',
    r'hot_tub\outdoor',
    r'house',
    r'ice_cream_parlor',
    r'industrial_area',
    r'jail\indoor',
    r'kiosk\outdoor',
    r'kitchen',
    r'labyrinth\outdoor',
    r'lake\natural',
    r'library\indoor',
    r'market\outdoor',
    r'mini_golf_course\outdoor',
    r'mosque\outdoor',
    r'mountain',
    r'mountain_path',
    r'movie_theater\indoor',
    r'office',
    r'park',
    r'pasture',
    r'patio',
    r'playground',
    r'plaza',
    r'raceway',
    r'restaurant',
    r'river',
    r'sauna',
    r'sea_cliff',
    r'skatepark',
    r'ski_slope',
    r'sky',
    r'stadium\baseball',
    r'stadium\outdoor',
    r'stage\outdoor',
    r'staircase',
    r'street',
    r'swimming_pool\outdoor',
    r'tennis_court\outdoor',
    r'tent\outdoor',
    r'tower',
    r'train_station\platform',
    r'underwater\ocean_shallow',
    r'waterfall\plunge',
    r'wine_cellar\bottle_storage',
    r'ziggurat',
    r'zoo',
]

new_names = [
    r'airport',
    r'alley',
    r'amusement_park',
    r'art_gallery',
    r'bakery',
    r'bar',
    r'basketball',
    r'bathroom',
    r'beach',
    r'outdoor_seating',
    r'bike',
    r'botanical_garden',
    r'bowling',
    r'boxing',
    r'brewing',
    r'bridge',
    r'bus',
    r'canal',
    r'casino',
    r'castle',
    r'cathedral_nave',
    r'cemetery',
    r'chalet',
    r'church',
    r'city',
    r'classroom',
    r'desert',
    r'dining_hall',
    r'nightclub',
    r'dock',
    r'golf',
    r'factory',
    r'field',
    r'highroad',
    r'pond',
    r'florist',
    r'trail',
    r'fountain',
    r'freeway',
    r'gym',
    r'harbor',
    r'hospital',
    r'hot_tub',
    r'house',
    r'ice_cream_parlor',
    r'industry',
    r'prison',
    r'kiosk',
    r'kitchen',
    r'labyrinth',
    r'lake',
    r'library',
    r'market',
    r'minigolf',
    r'mosque',
    r'mountain',
    r'hiking_trail',
    r'cinema',
    r'office',
    r'park',
    r'pasture',
    r'patio',
    r'playground',
    r'square',
    r'raceway',
    r'restaurant',
    r'river',
    r'sauna',
    r'cliff',
    r'skateboarding',
    r'skiing',
    r'sky',
    r'baseball',
    r'arena',
    r'concert',
    r'stairs',
    r'street',
    r'swimming_pool',
    r'tennis',
    r'tenting',
    r'tower',
    r'station',
    r'underwater',
    r'waterfall',
    r'wine_cellar',
    r'ziggurat',
    r'zoo',
]

# %%
import numpy as np

new_dict = {}
for i, old in enumerate(original_names):
    new_dict[old] = [(new_names[i], w2v[new_names[i]])]
    
with open('../../../data/new_scene_names.npy', 'wb+') as f:
    np.save(f, new_dict)
